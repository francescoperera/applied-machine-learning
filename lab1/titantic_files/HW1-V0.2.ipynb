# %%
import numpy as np
import csv
from sklearn.cross_validation import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn import svm
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.externals import joblib
from sklearn.metrics import roc_curve, auc
from sklearn.cross_validation import train_test_split
from sklearn.cross_validation import StratifiedKFold
from scipy import interp
from  matplotlib import pyplot as plt
from sklearn import cross_validation
import pandas as pd
from sklearn.preprocessing import OneHotEncoder
from sklearn.feature_extraction import DictVectorizer
from sklearn.metrics import roc_auc_score
from sklearn import metrics

# %%
data = pd.read_csv('train.csv')

# %%
data.drop(data.columns[[0, 3]], axis=1, inplace=True)

# %%
data['Sex'] = data['Sex'].map({'female': 1, 'male': 0})

# %%
data.head(n=5)
# Out:
#    Survived  Pclass  Sex  Age  SibSp  Parch     Fare  Ticket_enc  Cabin_enc  \
# 0         0       3    0   22      1      0   7.2500           0         -1
# 1         1       1    1   38      1      0  71.2833           1          0
# 2         1       3    1   26      0      0   7.9250           2         -1
# 3         1       1    1   35      1      0  53.1000           3          1
# 4         0       3    0   35      0      0   8.0500           4         -1
#
#    Embarked_enc
# 0             0
# 1             1
# 2             0
# 3             0
# 4             0

# %%
data.fillna(data.mean())
# Out:
#      Survived  Pclass  Sex        Age  SibSp  Parch            Ticket  \
# 0           0       3    0  22.000000      1      0         A/5 21171
# 1           1       1    1  38.000000      1      0          PC 17599
# 2           1       3    1  26.000000      0      0  STON/O2. 3101282
# 3           1       1    1  35.000000      1      0            113803
# 4           0       3    0  35.000000      0      0            373450
# 5           0       3    0  29.699118      0      0            330877
# 6           0       1    0  54.000000      0      0             17463
# 7           0       3    0   2.000000      3      1            349909
# 8           1       3    1  27.000000      0      2            347742
# 9           1       2    1  14.000000      1      0            237736
# 10          1       3    1   4.000000      1      1           PP 9549
# 11          1       1    1  58.000000      0      0            113783
# 12          0       3    0  20.000000      0      0         A/5. 2151
# 13          0       3    0  39.000000      1      5            347082
# 14          0       3    1  14.000000      0      0            350406
# 15          1       2    1  55.000000      0      0            248706
# 16          0       3    0   2.000000      4      1            382652
# 17          1       2    0  29.699118      0      0            244373
# 18          0       3    1  31.000000      1      0            345763
# 19          1       3    1  29.699118      0      0              2649
# 20          0       2    0  35.000000      0      0            239865
# 21          1       2    0  34.000000      0      0            248698
# 22          1       3    1  15.000000      0      0            330923
# 23          1       1    0  28.000000      0      0            113788
# 24          0       3    1   8.000000      3      1            349909
# 25          1       3    1  38.000000      1      5            347077
# 26          0       3    0  29.699118      0      0              2631
# 27          0       1    0  19.000000      3      2             19950
# 28          1       3    1  29.699118      0      0            330959
# 29          0       3    0  29.699118      0      0            349216
# ..        ...     ...  ...        ...    ...    ...               ...
# 861         0       2    0  21.000000      1      0             28134
# 862         1       1    1  48.000000      0      0             17466
# 863         0       3    1  29.699118      8      2          CA. 2343
# 864         0       2    0  24.000000      0      0            233866
# 865         1       2    1  42.000000      0      0            236852
# 866         1       2    1  27.000000      1      0     SC/PARIS 2149
# 867         0       1    0  31.000000      0      0          PC 17590
# 868         0       3    0  29.699118      0      0            345777
# 869         1       3    0   4.000000      1      1            347742
# 870         0       3    0  26.000000      0      0            349248
# 871         1       1    1  47.000000      1      1             11751
# 872         0       1    0  33.000000      0      0               695
# 873         0       3    0  47.000000      0      0            345765
# 874         1       2    1  28.000000      1      0         P/PP 3381
# 875         1       3    1  15.000000      0      0              2667
# 876         0       3    0  20.000000      0      0              7534
# 877         0       3    0  19.000000      0      0            349212
# 878         0       3    0  29.699118      0      0            349217
# 879         1       1    1  56.000000      0      1             11767
# 880         1       2    1  25.000000      0      1            230433
# 881         0       3    0  33.000000      0      0            349257
# 882         0       3    1  22.000000      0      0              7552
# 883         0       2    0  28.000000      0      0  C.A./SOTON 34068
# 884         0       3    0  25.000000      0      0   SOTON/OQ 392076
# 885         0       3    1  39.000000      0      5            382652
# 886         0       2    0  27.000000      0      0            211536
# 887         1       1    1  19.000000      0      0            112053
# 888         0       3    1  29.699118      1      2        W./C. 6607
# 889         1       1    0  26.000000      0      0            111369
# 890         0       3    0  32.000000      0      0            370376
#
#          Fare        Cabin Embarked
# 0      7.2500          NaN        S
# 1     71.2833          C85        C
# 2      7.9250          NaN        S
# 3     53.1000         C123        S
# 4      8.0500          NaN        S
# 5      8.4583          NaN        Q
# 6     51.8625          E46        S
# 7     21.0750          NaN        S
# 8     11.1333          NaN        S
# 9     30.0708          NaN        C
# 10    16.7000           G6        S
# 11    26.5500         C103        S
# 12     8.0500          NaN        S
# 13    31.2750          NaN        S
# 14     7.8542          NaN        S
# 15    16.0000          NaN        S
# 16    29.1250          NaN        Q
# 17    13.0000          NaN        S
# 18    18.0000          NaN        S
# 19     7.2250          NaN        C
# 20    26.0000          NaN        S
# 21    13.0000          D56        S
# 22     8.0292          NaN        Q
# 23    35.5000           A6        S
# 24    21.0750          NaN        S
# 25    31.3875          NaN        S
# 26     7.2250          NaN        C
# 27   263.0000  C23 C25 C27        S
# 28     7.8792          NaN        Q
# 29     7.8958          NaN        S
# ..        ...          ...      ...
# 861   11.5000          NaN        S
# 862   25.9292          D17        S
# 863   69.5500          NaN        S
# 864   13.0000          NaN        S
# 865   13.0000          NaN        S
# 866   13.8583          NaN        C
# 867   50.4958          A24        S
# 868    9.5000          NaN        S
# 869   11.1333          NaN        S
# 870    7.8958          NaN        S
# 871   52.5542          D35        S
# 872    5.0000  B51 B53 B55        S
# 873    9.0000          NaN        S
# 874   24.0000          NaN        C
# 875    7.2250          NaN        C
# 876    9.8458          NaN        S
# 877    7.8958          NaN        S
# 878    7.8958          NaN        S
# 879   83.1583          C50        C
# 880   26.0000          NaN        S
# 881    7.8958          NaN        S
# 882   10.5167          NaN        S
# 883   10.5000          NaN        S
# 884    7.0500          NaN        S
# 885   29.1250          NaN        Q
# 886   13.0000          NaN        S
# 887   30.0000          B42        S
# 888   23.4500          NaN        S
# 889   30.0000         C148        C
# 890    7.7500          NaN        Q
#
# [891 rows x 10 columns]

# %%
data['Ticket_enc'] = pd.factorize(data['Ticket'])[0]
data['Cabin_enc'] = pd.factorize(data['Cabin'])[0]
data['Embarked_enc'] = pd.factorize(data['Embarked'])[0]

# %%
data.head(n=5)
# Out:
#    Survived  Pclass  Sex  Age  SibSp  Parch     Fare  Ticket_enc  Cabin_enc  \
# 0         0       3    0   22      1      0   7.2500           0         -1
# 1         1       1    1   38      1      0  71.2833           1          0
# 2         1       3    1   26      0      0   7.9250           2         -1
# 3         1       1    1   35      1      0  53.1000           3          1
# 4         0       3    0   35      0      0   8.0500           4         -1
#
#    Embarked_enc
# 0             0
# 1             1
# 2             0
# 3             0
# 4             0

# %%
data.drop(data.columns[[6, 8, 9]], axis=1, inplace=True)

# %%
data.head(n=5)
# Out:
#    Survived  Pclass  Sex  Age  SibSp  Parch     Fare  Ticket_enc  Cabin_enc  \
# 0         0       3    0   22      1      0   7.2500           0         -1
# 1         1       1    1   38      1      0  71.2833           1          0
# 2         1       3    1   26      0      0   7.9250           2         -1
# 3         1       1    1   35      1      0  53.1000           3          1
# 4         0       3    0   35      0      0   8.0500           4         -1
#
#    Embarked_enc
# 0             0
# 1             1
# 2             0
# 3             0
# 4             0

# %%
data = data.fillna(data.mean())

# %%
data.head(n=5)
# Out:
#    Survived  Pclass  Sex  Age  SibSp  Parch     Fare  Ticket_enc  Cabin_enc  \
# 0         0       3    0   22      1      0   7.2500           0         -1
# 1         1       1    1   38      1      0  71.2833           1          0
# 2         1       3    1   26      0      0   7.9250           2         -1
# 3         1       1    1   35      1      0  53.1000           3          1
# 4         0       3    0   35      0      0   8.0500           4         -1
#
#    Embarked_enc
# 0             0
# 1             1
# 2             0
# 3             0
# 4             0

# %%
data.head(n=5)
# Out:
#    Pclass  Sex  Age  SibSp  Parch     Fare  Ticket_enc  Cabin_enc  \
# 0       3    0   22      1      0   7.2500           0         -1
# 1       1    1   38      1      0  71.2833           1          0
# 2       3    1   26      0      0   7.9250           2         -1
# 3       1    1   35      1      0  53.1000           3          1
# 4       3    0   35      0      0   8.0500           4         -1
#
#    Embarked_enc
# 0             0
# 1             1
# 2             0
# 3             0
# 4             0

# %%
y = data['Survived'].as_matrix()

# %%
X =data.iloc[:,1:].values

# %%
print(len(y))
# Out:
# 891

# %%
clf = LogisticRegression()

# %%
X_train, X_test, y_train, y_test = cross_validation.train_test_split(
    X, y, test_size=0.25, random_state=42)

# %%
# X_train, X_test, y_train, y_test = cross_validation.train_test_split(
# X, y, test_size=0.4, random_state=0)

# %%
clf.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr',
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0)

# %%
scores = cross_validation.cross_val_score(clf, X, y, cv=5)

# %%
print("Accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))
# Out:
# Accuracy: 0.79 (+/- 0.04)

# %%
print(np.exp(clf.intercept_), np.exp(clf.coef_.ravel()))
# Out:
# [ 0.42916779] [ 12.8581696    0.97292362   0.71429975   0.81726769   1.01054981
#    0.99955761   1.01555829   1.08749629]

# %%
from sklearn.metrics import precision_recall_curve
precision, recall, thresholds = precision_recall_curve(y_test,
    clf.predict(X_test))

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test, clf.predict(X_test),
    target_names=['Survived', 'Not Survived']))
# Out:
#               precision    recall  f1-score   support
#
#     Survived       0.81      0.84      0.82       134
# Not Survived       0.74      0.71      0.72        89
#
#  avg / total       0.78      0.78      0.78       223

# %%
print(clf.intercept_)
# Out:
# [-0.84590733]

# %%
preds = clf.predict(X_test)

# %%
print(preds[0:2])
# Out:
# [[ 0.88071956  0.11928044]
#  [ 0.85404648  0.14595352]]

# %%
len(preds)
# Out:
# 223

# %%
roc_auc_score(y_test, preds, average='macro')
# Out:
# 0.77184303203085691

# %%
fpr, tpr, thresholds = metrics.roc_curve(y_test, preds)
